# %%
from db import get_engine, df_from_sql
engine = get_engine()

sql_count = """
SELECT COUNT(*) AS n
FROM public.profiles
WHERE linkedin_url ~* '^(https?://)www\\.public\\.com/';
"""
sql_sample = """
SELECT profile_id, linkedin_url
FROM public.profiles
WHERE linkedin_url ~* '^(https?://)www\\.public\\.com/'
ORDER BY profile_id
LIMIT 20;
"""

print("🔎 Conteo de filas con dominio incorrecto:")
print(df_from_sql(sql_count, engine))

print("\n🧪 Muestra (20 filas):")
df_from_sql(sql_sample, engine)
# Out:
# 🔎 Conteo de filas con dominio incorrecto:
#      n
# 0  445
#
# 🧪 Muestra (20 filas):
#     profile_id                                       linkedin_url
# 0            1   https://www.public.com/in/iara-bessone-1b9047186
# 1            2  https://www.public.com/in/geraldine-beskow-b96...
# 2            3             https://www.public.com/in/agustinbesso
# 3            4             https://www.public.com/in/agustinabetz
# 4            5       https://www.public.com/in/santiagobianciotti
# 5            6      https://www.public.com/in/gonzaloblaconasainz
# 6            7              https://www.public.com/in/pbiondi1989
# 7            8                 https://www.public.com/in/fdbianco
# 8            9             https://www.public.com/in/meli-bircher
# 9           10           https://www.public.com/in/blancoezequiel
# 10          11                 https://www.public.com/in/alfre144
# 11          12   https://www.public.com/in/lorena-blanco-19361419
# 12          13  https://www.public.com/in/gabriela-bled-monsal...
# 13          14          https://www.public.com/in/delfinablousson
# 14          15  https://www.public.com/in/emiliana-bodega-4813...
# 15          16    https://www.public.com/in/maria-luz-boero-ux-ui
# 16          17           https://www.public.com/in/santiago-boeri
# 17          18                https://www.public.com/in/fbogliolo
# 18          19        https://www.public.com/in/sofiabohnguixeras
# 19          20            https://www.public.com/in/tomasguixeras

# %%
import pandas as pd
import os, datetime as dt

backup_dir = "../backups"
os.makedirs(backup_dir, exist_ok=True)
ts = dt.datetime.now().strftime("%Y%m%d_%H%M%S")

sql_backup = """
SELECT *
FROM public.profiles
WHERE linkedin_url ~* '^(https?://)www\\.public\\.com/';
"""
df_backup = df_from_sql(sql_backup, engine)
backup_path = os.path.join(backup_dir, f"profiles_public_domain_backup_{ts}.csv")
df_backup.to_csv(backup_path, index=False, encoding="utf-8")
backup_path
# Out:
# '../backups\\profiles_public_domain_backup_20251030_011307.csv'

# %%
from sqlalchemy import text

update_sql = text("""
UPDATE public.profiles
SET linkedin_url = regexp_replace(
    linkedin_url,
    '^(https?://)www\\.public\\.com/',
    '\\1www.linkedin.com/'
)
WHERE linkedin_url ~* '^(https?://)www\\.public\\.com/'
RETURNING profile_id, linkedin_url;
""")

updated = []
with engine.begin() as conn:  # transacción
    res = conn.execute(update_sql)
    updated = res.mappings().all()

print(f"✅ Filas actualizadas: {len(updated)}")
# Mostrar algunas filas resultantes
import pandas as pd
pd.DataFrame(updated).head(20)
# Out:
# ---------------------------------------------------------------------------
# UniqueViolation                           Traceback (most recent call last)
# File d:\LATAM CONNECT\talento_latam_connect_V0.0\extraccion_talento_latam_connect\.venv\Lib\site-packages\sqlalchemy\engine\base.py:1967, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1966     if not evt_handled:
# -> 1967         self.dialect.do_execute(
#    1968             cursor, str_statement, effective_parameters, context
#    1969         )
#    1971 if self._has_events or self.engine._has_events:
#
# File d:\LATAM CONNECT\talento_latam_connect_V0.0\extraccion_talento_latam_connect\.venv\Lib\site-packages\sqlalchemy\engine\default.py:951, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     950 def do_execute(self, cursor, statement, parameters, context=None):
# --> 951     cursor.execute(statement, parameters)
#
# UniqueViolation: duplicate key value violates unique constraint "profiles_linkedin_url_key"
# DETAIL:  Key (linkedin_url)=(https://www.linkedin.com/in/iara-bessone-1b9047186) already exists.
#
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# Cell In[11], line 16
#      14 updated = []
#      15 with engine.begin() as conn:  # transacción
# ---> 16     res = conn.execute(update_sql)
#      17     updated = res.mappings().all()
#      19 print(f"✅ Filas actualizadas: {len(updated)}")
#
# File d:\LATAM CONNECT\talento_latam_connect_V0.0\extraccion_talento_latam_connect\.venv\Lib\site-packages\sqlalchemy\engine\base.py:1419, in Connection.execute(self, statement, parameters, execution_options)
#    1417     raise exc.ObjectNotExecutableError(statement) from err
#    1418 else:
# -> 1419     return meth(
#    1420         self,
#    1421         distilled_parameters,
#    1422         execution_options or NO_OPTIONS,
#    1423     )
#
# File d:\LATAM CONNECT\talento_latam_connect_V0.0\extraccion_talento_latam_connect\.venv\Lib\site-packages\sqlalchemy\sql\elements.py:526, in ClauseElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     524     if TYPE_CHECKING:
#     525         assert isinstance(self, Executable)
# --> 526     return connection._execute_clauseelement(
#     527         self, distilled_params, execution_options
#     528     )
#     529 else:
#     530     raise exc.ObjectNotExecutableError(self)
#
# File d:\LATAM CONNECT\talento_latam_connect_V0.0\extraccion_talento_latam_connect\.venv\Lib\site-packages\sqlalchemy\engine\base.py:1641, in Connection._execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1629 compiled_cache: Optional[CompiledCacheType] = execution_options.get(
#    1630     "compiled_cache", self.engine._compiled_cache
#    1631 )
#    1633 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1634     dialect=dialect,
#    1635     compiled_cache=compiled_cache,
#    (...)   1639     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1640 )
# -> 1641 ret = self._execute_context(
#    1642     dialect,
#    1643     dialect.execution_ctx_cls._init_compiled,
#    1644     compiled_sql,
#    1645     distilled_parameters,
#    1646     execution_options,
#    1647     compiled_sql,
#    1648     distilled_parameters,
#    1649     elem,
#    1650     extracted_params,
#    1651     cache_hit=cache_hit,
#    1652 )
#    1653 if has_events:
#    1654     self.dispatch.after_execute(
#    1655         self,
#    1656         elem,
#    (...)   1660         ret,
#    1661     )
#
# File d:\LATAM CONNECT\talento_latam_connect_V0.0\extraccion_talento_latam_connect\.venv\Lib\site-packages\sqlalchemy\engine\base.py:1846, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1844     return self._exec_insertmany_context(dialect, context)
#    1845 else:
# -> 1846     return self._exec_single_context(
#    1847         dialect, context, statement, parameters
#    1848     )
#
# File d:\LATAM CONNECT\talento_latam_connect_V0.0\extraccion_talento_latam_connect\.venv\Lib\site-packages\sqlalchemy\engine\base.py:1986, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1983     result = context._setup_result_proxy()
#    1985 except BaseException as e:
# -> 1986     self._handle_dbapi_exception(
#    1987         e, str_statement, effective_parameters, cursor, context
#    1988     )
#    1990 return result
#
# File d:\LATAM CONNECT\talento_latam_connect_V0.0\extraccion_talento_latam_connect\.venv\Lib\site-packages\sqlalchemy\engine\base.py:2355, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2353 elif should_wrap:
#    2354     assert sqlalchemy_exception is not None
# -> 2355     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2356 else:
#    2357     assert exc_info[1] is not None
#
# File d:\LATAM CONNECT\talento_latam_connect_V0.0\extraccion_talento_latam_connect\.venv\Lib\site-packages\sqlalchemy\engine\base.py:1967, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1965                 break
#    1966     if not evt_handled:
# -> 1967         self.dialect.do_execute(
#    1968             cursor, str_statement, effective_parameters, context
#    1969         )
#    1971 if self._has_events or self.engine._has_events:
#    1972     self.dispatch.after_cursor_execute(
#    1973         self,
#    1974         cursor,
#    (...)   1978         context.executemany,
#    1979     )
#
# File d:\LATAM CONNECT\talento_latam_connect_V0.0\extraccion_talento_latam_connect\.venv\Lib\site-packages\sqlalchemy\engine\default.py:951, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     950 def do_execute(self, cursor, statement, parameters, context=None):
# --> 951     cursor.execute(statement, parameters)
#
# IntegrityError: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "profiles_linkedin_url_key"
# DETAIL:  Key (linkedin_url)=(https://www.linkedin.com/in/iara-bessone-1b9047186) already exists.
#
# [SQL:
# UPDATE public.profiles
# SET linkedin_url = regexp_replace(
#     linkedin_url,
#     '^(https?://)www\.public\.com/',
#     '\1www.linkedin.com/'
# )
# WHERE linkedin_url ~* '^(https?://)www\.public\.com/'
# RETURNING profile_id, linkedin_url;
# ]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)

# %%
preview_pairs_sql = """
WITH bad AS (
  SELECT
    rtrim(lower(linkedin_url), '/')            AS bad_url_norm,
    rtrim(lower(
      regexp_replace(linkedin_url,
        '^(https?://)www\\.public\\.com/',
        '\\1www.linkedin.com/'
      )
    ), '/')                                   AS target_url_norm
  FROM public.profiles
  WHERE linkedin_url ~* '^(https?://)www\\.public\\.com/'
)
SELECT
  p_bad.linkedin_url         AS will_update_from,
  p_dup.linkedin_url         AS existing_target_conflict
FROM bad b
JOIN public.profiles p_bad
  ON rtrim(lower(p_bad.linkedin_url), '/') = b.bad_url_norm
JOIN public.profiles p_dup
  ON rtrim(lower(p_dup.linkedin_url), '/') = b.target_url_norm
ORDER BY p_bad.linkedin_url
LIMIT 50;
"""
df_from_sql(preview_pairs_sql, engine)
# Out:
#                                      will_update_from                           existing_target_conflict
# 0                   https://www.public.com/in/1500336                https://www.linkedin.com/in/1500336
# 1   https://www.public.com/in/adib-abuslaiman-7901...  https://www.linkedin.com/in/adib-abuslaiman-79...
# 2          https://www.public.com/in/adrian-benavides       https://www.linkedin.com/in/adrian-benavides
# 3                https://www.public.com/in/agjosefina             https://www.linkedin.com/in/agjosefina
# 4         https://www.public.com/in/agostina-buffagni      https://www.linkedin.com/in/agostina-buffagni
# 5   https://www.public.com/in/agustina-beltramino-...  https://www.linkedin.com/in/agustina-beltramin...
# 6              https://www.public.com/in/agustinabetz           https://www.linkedin.com/in/agustinabetz
# 7   https://www.public.com/in/agustin-alonso-canto...  https://www.linkedin.com/in/agustin-alonso-can...
# 8    https://www.public.com/in/agustin-avalos-tabasso  https://www.linkedin.com/in/agustin-avalos-tab...
# 9              https://www.public.com/in/agustinbesso           https://www.linkedin.com/in/agustinbesso
# 10            https://www.public.com/in/agus-varela10          https://www.linkedin.com/in/agus-varela10
# 11          https://www.public.com/in/alarconfernanda        https://www.linkedin.com/in/alarconfernanda
# 12              https://www.public.com/in/albana-alza            https://www.linkedin.com/in/albana-alza
# 13           https://www.public.com/in/aldo-bassanini         https://www.linkedin.com/in/aldo-bassanini
# 14  https://www.public.com/in/alejandra-barbero-96...  https://www.linkedin.com/in/alejandra-barbero-...
# 15  https://www.public.com/in/alejandro-bacigalupo...  https://www.linkedin.com/in/alejandro-bacigalu...
# 16                 https://www.public.com/in/alfre144               https://www.linkedin.com/in/alfre144
# 17  https://www.public.com/in/alfredo-sangbum-cho-...  https://www.linkedin.com/in/alfredo-sangbum-ch...
# 18            https://www.public.com/in/alvaradotomas          https://www.linkedin.com/in/alvaradotomas
# 19      https://www.public.com/in/alvarobarcellmacedo    https://www.linkedin.com/in/alvarobarcellmacedo
# 20           https://www.public.com/in/amelia-buscemi         https://www.linkedin.com/in/amelia-buscemi
# 21                 https://www.public.com/in/ameriomb               https://www.linkedin.com/in/ameriomb
# 22                https://www.public.com/in/ammicaela              https://www.linkedin.com/in/ammicaela
# 23  https://www.public.com/in/ana-belén-alberti-1a...  https://www.linkedin.com/in/ana-belén-alberti-...
# 24     https://www.public.com/in/anabenaventealmécija   https://www.linkedin.com/in/anabenaventealmécija
# 25     https://www.public.com/in/ana-bossler-07304717   https://www.linkedin.com/in/ana-bossler-07304717
# 26           https://www.public.com/in/ana-c-4338971a         https://www.linkedin.com/in/ana-c-4338971a
# 27  https://www.public.com/in/analía-alvarez-md-52...  https://www.linkedin.com/in/analía-alvarez-md-...
# 28           https://www.public.com/in/analiajaguilar         https://www.linkedin.com/in/analiajaguilar
# 29             https://www.public.com/in/anamejalenko           https://www.linkedin.com/in/anamejalenko
# 30          https://www.public.com/in/anderssongaston        https://www.linkedin.com/in/anderssongaston
# 31    https://www.public.com/in/andrea-apolo-montalvo  https://www.linkedin.com/in/andrea-apolo-montalvo
# 32      https://www.public.com/in/andresmartinarrieta    https://www.linkedin.com/in/andresmartinarrieta
# 33                https://www.public.com/in/angelaaco              https://www.linkedin.com/in/angelaaco
# 34     https://www.public.com/in/anibal-ayala-3222049   https://www.linkedin.com/in/anibal-ayala-3222049
# 35     https://www.public.com/in/annabalaguergrimaldo   https://www.linkedin.com/in/annabalaguergrimaldo
# 36         https://www.public.com/in/antonelabrianese       https://www.linkedin.com/in/antonelabrianese
# 37   https://www.public.com/in/ariel-ansaldi-65131723  https://www.linkedin.com/in/ariel-ansaldi-6513...
# 38              https://www.public.com/in/arielgbrusa            https://www.linkedin.com/in/arielgbrusa
# 39                https://www.public.com/in/armengouc              https://www.linkedin.com/in/armengouc
# 40         https://www.public.com/in/arqmartinbarrozo       https://www.linkedin.com/in/arqmartinbarrozo
# 41  https://www.public.com/in/arquitectura-diseño-...  https://www.linkedin.com/in/arquitectura-diseñ...
# 42  https://www.public.com/in/augusto-barrero-6b47...  https://www.linkedin.com/in/augusto-barrero-6b...
# 43  https://www.public.com/in/augusto-bonomo-58a97293  https://www.linkedin.com/in/augusto-bonomo-58a...
# 44   https://www.public.com/in/axel-batalla-91abb716a  https://www.linkedin.com/in/axel-batalla-91abb...
# 45      https://www.public.com/in/barbara-b-4b92b9181    https://www.linkedin.com/in/barbara-b-4b92b9181
# 46          https://www.public.com/in/bautista-amadeo        https://www.linkedin.com/in/bautista-amadeo
# 47         https://www.public.com/in/belénlópezparodi       https://www.linkedin.com/in/belénlópezparodi
# 48           https://www.public.com/in/blancoezequiel         https://www.linkedin.com/in/blancoezequiel
# 49  https://www.public.com/in/braian-burgardt-0370...  https://www.linkedin.com/in/braian-burgardt-03...

# %%
from db import get_engine, df_from_sql
engine = get_engine()

preview_pairs = """
WITH pairs AS (
  SELECT
    keep.profile_id  AS keep_id,   -- conservamos esta (tiene public.com)
    drop_.profile_id AS drop_id,   -- borraremos esta (ya tiene linkedin.com)
    keep.linkedin_url AS keep_url_before,
    drop_.linkedin_url AS drop_url_existing
  FROM public.profiles keep
  JOIN public.profiles drop_
    ON rtrim(lower(
         regexp_replace(keep.linkedin_url,
           '^(https?://)www\\.public\\.com/', '\\1www.linkedin.com/'
         )
       ), '/') = rtrim(lower(drop_.linkedin_url), '/')
  WHERE keep.linkedin_url ~* '^(https?://)www\\.public\\.com/'
)
SELECT * FROM pairs
ORDER BY keep_id
LIMIT 50;
"""
df_from_sql(preview_pairs, engine)
# Out:
#     keep_id  drop_id                                    keep_url_before                                  drop_url_existing
# 0         1     3337   https://www.public.com/in/iara-bessone-1b9047186  https://www.linkedin.com/in/iara-bessone-1b904...
# 1         2     3335  https://www.public.com/in/geraldine-beskow-b96...  https://www.linkedin.com/in/geraldine-beskow-b...
# 2         3     3336             https://www.public.com/in/agustinbesso           https://www.linkedin.com/in/agustinbesso
# 3         4     3338             https://www.public.com/in/agustinabetz           https://www.linkedin.com/in/agustinabetz
# 4         5     3340       https://www.public.com/in/santiagobianciotti     https://www.linkedin.com/in/santiagobianciotti
# 5         6     3348      https://www.public.com/in/gonzaloblaconasainz    https://www.linkedin.com/in/gonzaloblaconasainz
# 6         7     3344              https://www.public.com/in/pbiondi1989            https://www.linkedin.com/in/pbiondi1989
# 7         8     3341                 https://www.public.com/in/fdbianco               https://www.linkedin.com/in/fdbianco
# 8         9     3345             https://www.public.com/in/meli-bircher           https://www.linkedin.com/in/meli-bircher
# 9        10     3349           https://www.public.com/in/blancoezequiel         https://www.linkedin.com/in/blancoezequiel
# 10       11     3354                 https://www.public.com/in/alfre144               https://www.linkedin.com/in/alfre144
# 11       12     3351   https://www.public.com/in/lorena-blanco-19361419  https://www.linkedin.com/in/lorena-blanco-1936...
# 12       13     3355  https://www.public.com/in/gabriela-bled-monsal...  https://www.linkedin.com/in/gabriela-bled-mons...
# 13       14     3356          https://www.public.com/in/delfinablousson        https://www.linkedin.com/in/delfinablousson
# 14       15     3357  https://www.public.com/in/emiliana-bodega-4813...  https://www.linkedin.com/in/emiliana-bodega-48...
# 15       16     3360    https://www.public.com/in/maria-luz-boero-ux-ui  https://www.linkedin.com/in/maria-luz-boero-ux-ui
# 16       17     3359           https://www.public.com/in/santiago-boeri         https://www.linkedin.com/in/santiago-boeri
# 17       18     3362                https://www.public.com/in/fbogliolo              https://www.linkedin.com/in/fbogliolo
# 18       19     3365        https://www.public.com/in/sofiabohnguixeras      https://www.linkedin.com/in/sofiabohnguixeras
# 19       20     3366            https://www.public.com/in/tomasguixeras          https://www.linkedin.com/in/tomasguixeras
# 20       21     3368            https://www.public.com/in/mauricioboiko          https://www.linkedin.com/in/mauricioboiko
# 21       23     3369           https://www.public.com/in/yanina-boillat         https://www.linkedin.com/in/yanina-boillat
# 22       24     3372            https://www.public.com/in/marianabolado          https://www.linkedin.com/in/marianabolado
# 23       25     3371              https://www.public.com/in/laurabolado            https://www.linkedin.com/in/laurabolado
# 24       26     3374           https://www.public.com/in/guidobolognini         https://www.linkedin.com/in/guidobolognini
# 25       27     3377            https://www.public.com/in/lucilabonardi          https://www.linkedin.com/in/lucilabonardi
# 26       28     3379                   https://www.public.com/in/ibonel                 https://www.linkedin.com/in/ibonel
# 27       29     3380    https://www.public.com/in/felipe-bonet-249ab5b6  https://www.linkedin.com/in/felipe-bonet-249ab5b6
# 28       30     3384       https://www.public.com/in/marianabonnesserre     https://www.linkedin.com/in/marianabonnesserre
# 29       31     3381            https://www.public.com/in/julia-bonetto          https://www.linkedin.com/in/julia-bonetto
# 30       32     3387  https://www.public.com/in/augusto-bonomo-58a97293  https://www.linkedin.com/in/augusto-bonomo-58a...
# 31       33     3388            https://www.public.com/in/lara-bontorno          https://www.linkedin.com/in/lara-bontorno
# 32       34     3390  https://www.public.com/in/martin-bordagaray-35...  https://www.linkedin.com/in/martin-bordagaray-...
# 33       35     3392            https://www.public.com/in/nicolas-boria          https://www.linkedin.com/in/nicolas-boria
# 34       36     3395  https://www.public.com/in/hovannes-borras-gurl...  https://www.linkedin.com/in/hovannes-borras-gu...
# 35       37     3393          https://www.public.com/in/brunela-boriosi        https://www.linkedin.com/in/brunela-boriosi
# 36       38     3397        https://www.public.com/in/florenciaborrilli      https://www.linkedin.com/in/florenciaborrilli
# 37       39     3398    https://www.public.com/in/marianoborsiniparajon  https://www.linkedin.com/in/marianoborsiniparajon
# 38       40     3399  https://www.public.com/in/lucas-bortignon-0444...  https://www.linkedin.com/in/lucas-bortignon-04...
# 39       41     3403              https://www.public.com/in/gabrielboso            https://www.linkedin.com/in/gabrielboso
# 40       42     3400            https://www.public.com/in/morganeborzee          https://www.linkedin.com/in/morganeborzee
# 41       43     3402  https://www.public.com/in/juan-pablo-bosio-a12...  https://www.linkedin.com/in/juan-pablo-bosio-a...
# 42       44     3401              https://www.public.com/in/juanpabosio            https://www.linkedin.com/in/juanpabosio
# 43       45     3407             https://www.public.com/in/gastonbossio           https://www.linkedin.com/in/gastonbossio
# 44       46     3405          https://www.public.com/in/florenciabossel        https://www.linkedin.com/in/florenciabossel
# 45       47     3406  https://www.public.com/in/luciana-bossel-2a95409b  https://www.linkedin.com/in/luciana-bossel-2a9...
# 46       48     3409           https://www.public.com/in/maria-bossotto         https://www.linkedin.com/in/maria-bossotto
# 47       49     3410   https://www.public.com/in/ciro-botello-276ba1137  https://www.linkedin.com/in/ciro-botello-276ba...
# 48       50     3408     https://www.public.com/in/ana-bossler-07304717   https://www.linkedin.com/in/ana-bossler-07304717
# 49       51     3412        https://www.public.com/in/javier-hugo-botta      https://www.linkedin.com/in/javier-hugo-botta

# %%
from sqlalchemy import text
from db import get_engine, df_from_sql

engine = get_engine()

with engine.begin() as conn:
    # 1) Pares keep/drop (keep = public.com, drop = linkedin.com)
    conn.execute(text("CREATE TEMP TABLE pairs(keep_id bigint, drop_id bigint) ON COMMIT DROP;"))

    conn.execute(text("""
        INSERT INTO pairs(keep_id, drop_id)
        SELECT
          keep.profile_id  AS keep_id,
          drop_.profile_id AS drop_id
        FROM public.profiles keep
        JOIN public.profiles drop_
          ON rtrim(lower(
               regexp_replace(keep.linkedin_url,
                 '^(https?://)www\\.public\\.com/', '\\1www.linkedin.com/'
               )
             ), '/') = rtrim(lower(drop_.linkedin_url), '/')
        WHERE keep.linkedin_url ~* '^(https?://)www\\.public\\.com/';
    """))

    # 2) Reasignar TODAS las FKs que referencian a public.profiles(profile_id)
    conn.execute(text("""
    DO $$
    DECLARE
      r RECORD;
    BEGIN
      FOR r IN
        SELECT
          n.nspname         AS fk_schema,
          c.relname         AS fk_table,
          a.attname         AS fk_column
        FROM pg_constraint ct
        JOIN pg_class c           ON c.oid = ct.conrelid
        JOIN pg_namespace n       ON n.oid = c.relnamespace
        JOIN pg_class cref        ON cref.oid = ct.confrelid
        JOIN pg_namespace nref    ON nref.oid = cref.relnamespace
        JOIN unnest(ct.conkey) WITH ORDINALITY AS ck(attnum, ord)
             JOIN pg_attribute a  ON a.attrelid = ct.conrelid AND a.attnum = ck.attnum
        WHERE ct.contype = 'f'
          AND nref.nspname = 'public'
          AND cref.relname = 'profiles'
      LOOP
        EXECUTE format($F$
          UPDATE %I.%I t
          SET %I = p.keep_id
          FROM pairs p
          WHERE t.%I = p.drop_id
        $F$, r.fk_schema, r.fk_table, r.fk_column, r.fk_column);
      END LOOP;
    END$$;
    """))

    # 3) Borrar duplicadas (las que ya tenían linkedin.com)
    del_res = conn.execute(text("""
        DELETE FROM public.profiles pr
        USING pairs p
        WHERE pr.profile_id = p.drop_id;
    """))

    # 4) Corregir dominio en las filas conservadas
    upd_res = conn.execute(text("""
        UPDATE public.profiles pr
        SET linkedin_url = regexp_replace(pr.linkedin_url,
                           '^(https?://)www\\.public\\.com/', '\\1www.linkedin.com/')
        FROM pairs p
        WHERE pr.profile_id = p.keep_id;
    """))

print("✅ Fusión completada.")
# Out:
# ---------------------------------------------------------------------------
# SyntaxError                               Traceback (most recent call last)
# File d:\LATAM CONNECT\talento_latam_connect_V0.0\extraccion_talento_latam_connect\.venv\Lib\site-packages\sqlalchemy\engine\base.py:1967, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1966     if not evt_handled:
# -> 1967         self.dialect.do_execute(
#    1968             cursor, str_statement, effective_parameters, context
#    1969         )
#    1971 if self._has_events or self.engine._has_events:
#
# File d:\LATAM CONNECT\talento_latam_connect_V0.0\extraccion_talento_latam_connect\.venv\Lib\site-packages\sqlalchemy\engine\default.py:951, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     950 def do_execute(self, cursor, statement, parameters, context=None):
# --> 951     cursor.execute(statement, parameters)
#
# SyntaxError: syntax error at or near "WHERE"
# LINE 18:         WHERE ct.contype = 'f'
#                  ^
#
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# Cell In[16], line 26
#      10 conn.execute(text("""
#      11     INSERT INTO pairs(keep_id, drop_id)
#      12     SELECT
#    (...)     22     WHERE keep.linkedin_url ~* '^(https?://)www\\.public\\.com/';
#      23 """))
#      25 # 2) Reasignar TODAS las FKs que referencian a public.profiles(profile_id)
# ---> 26 conn.execute(text("""
#      27 DO $$
#      28 DECLARE
#      29   r RECORD;
#      30 BEGIN
#      31   FOR r IN
#      32     SELECT
#      33       n.nspname         AS fk_schema,
#      34       c.relname         AS fk_table,
#      35       a.attname         AS fk_column
#      36     FROM pg_constraint ct
#      37     JOIN pg_class c           ON c.oid = ct.conrelid
#      38     JOIN pg_namespace n       ON n.oid = c.relnamespace
#      39     JOIN pg_class cref        ON cref.oid = ct.confrelid
#      40     JOIN pg_namespace nref    ON nref.oid = cref.relnamespace
#      41     JOIN unnest(ct.conkey) WITH ORDINALITY AS ck(attnum, ord)
#      42          JOIN pg_attribute a  ON a.attrelid = ct.conrelid AND a.attnum = ck.attnum
#      43     WHERE ct.contype = 'f'
#      44       AND nref.nspname = 'public'
#      45       AND cref.relname = 'profiles'
#      46   LOOP
#      47     EXECUTE format($F$
#      48       UPDATE %I.%I t
#      49       SET %I = p.keep_id
#      50       FROM pairs p
#      51       WHERE t.%I = p.drop_id
#      52     $F$, r.fk_schema, r.fk_table, r.fk_column, r.fk_column);
#      53   END LOOP;
#      54 END$$;
#      55 """))
#      57 # 3) Borrar duplicadas (las que ya tenían linkedin.com)
#      58 del_res = conn.execute(text("""
#      59     DELETE FROM public.profiles pr
#      60     USING pairs p
#      61     WHERE pr.profile_id = p.drop_id;
#      62 """))
#
# File d:\LATAM CONNECT\talento_latam_connect_V0.0\extraccion_talento_latam_connect\.venv\Lib\site-packages\sqlalchemy\engine\base.py:1419, in Connection.execute(self, statement, parameters, execution_options)
#    1417     raise exc.ObjectNotExecutableError(statement) from err
#    1418 else:
# -> 1419     return meth(
#    1420         self,
#    1421         distilled_parameters,
#    1422         execution_options or NO_OPTIONS,
#    1423     )
#
# File d:\LATAM CONNECT\talento_latam_connect_V0.0\extraccion_talento_latam_connect\.venv\Lib\site-packages\sqlalchemy\sql\elements.py:526, in ClauseElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     524     if TYPE_CHECKING:
#     525         assert isinstance(self, Executable)
# --> 526     return connection._execute_clauseelement(
#     527         self, distilled_params, execution_options
#     528     )
#     529 else:
#     530     raise exc.ObjectNotExecutableError(self)
#
# File d:\LATAM CONNECT\talento_latam_connect_V0.0\extraccion_talento_latam_connect\.venv\Lib\site-packages\sqlalchemy\engine\base.py:1641, in Connection._execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1629 compiled_cache: Optional[CompiledCacheType] = execution_options.get(
#    1630     "compiled_cache", self.engine._compiled_cache
#    1631 )
#    1633 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1634     dialect=dialect,
#    1635     compiled_cache=compiled_cache,
#    (...)   1639     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1640 )
# -> 1641 ret = self._execute_context(
#    1642     dialect,
#    1643     dialect.execution_ctx_cls._init_compiled,
#    1644     compiled_sql,
#    1645     distilled_parameters,
#    1646     execution_options,
#    1647     compiled_sql,
#    1648     distilled_parameters,
#    1649     elem,
#    1650     extracted_params,
#    1651     cache_hit=cache_hit,
#    1652 )
#    1653 if has_events:
#    1654     self.dispatch.after_execute(
#    1655         self,
#    1656         elem,
#    (...)   1660         ret,
#    1661     )
#
# File d:\LATAM CONNECT\talento_latam_connect_V0.0\extraccion_talento_latam_connect\.venv\Lib\site-packages\sqlalchemy\engine\base.py:1846, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1844     return self._exec_insertmany_context(dialect, context)
#    1845 else:
# -> 1846     return self._exec_single_context(
#    1847         dialect, context, statement, parameters
#    1848     )
#
# File d:\LATAM CONNECT\talento_latam_connect_V0.0\extraccion_talento_latam_connect\.venv\Lib\site-packages\sqlalchemy\engine\base.py:1986, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1983     result = context._setup_result_proxy()
#    1985 except BaseException as e:
# -> 1986     self._handle_dbapi_exception(
#    1987         e, str_statement, effective_parameters, cursor, context
#    1988     )
#    1990 return result
#
# File d:\LATAM CONNECT\talento_latam_connect_V0.0\extraccion_talento_latam_connect\.venv\Lib\site-packages\sqlalchemy\engine\base.py:2355, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2353 elif should_wrap:
#    2354     assert sqlalchemy_exception is not None
# -> 2355     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2356 else:
#    2357     assert exc_info[1] is not None
#
# File d:\LATAM CONNECT\talento_latam_connect_V0.0\extraccion_talento_latam_connect\.venv\Lib\site-packages\sqlalchemy\engine\base.py:1967, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1965                 break
#    1966     if not evt_handled:
# -> 1967         self.dialect.do_execute(
#    1968             cursor, str_statement, effective_parameters, context
#    1969         )
#    1971 if self._has_events or self.engine._has_events:
#    1972     self.dispatch.after_cursor_execute(
#    1973         self,
#    1974         cursor,
#    (...)   1978         context.executemany,
#    1979     )
#
# File d:\LATAM CONNECT\talento_latam_connect_V0.0\extraccion_talento_latam_connect\.venv\Lib\site-packages\sqlalchemy\engine\default.py:951, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     950 def do_execute(self, cursor, statement, parameters, context=None):
# --> 951     cursor.execute(statement, parameters)
#
# ProgrammingError: (psycopg2.errors.SyntaxError) syntax error at or near "WHERE"
# LINE 18:         WHERE ct.contype = 'f'
#                  ^
#
# [SQL:
#     DO $$
#     DECLARE
#       r RECORD;
#     BEGIN
#       FOR r IN
#         SELECT
#           n.nspname         AS fk_schema,
#           c.relname         AS fk_table,
#           a.attname         AS fk_column
#         FROM pg_constraint ct
#         JOIN pg_class c           ON c.oid = ct.conrelid
#         JOIN pg_namespace n       ON n.oid = c.relnamespace
#         JOIN pg_class cref        ON cref.oid = ct.confrelid
#         JOIN pg_namespace nref    ON nref.oid = cref.relnamespace
#         JOIN unnest(ct.conkey) WITH ORDINALITY AS ck(attnum, ord)
#              JOIN pg_attribute a  ON a.attrelid = ct.conrelid AND a.attnum = ck.attnum
#         WHERE ct.contype = 'f'
#           AND nref.nspname = 'public'
#           AND cref.relname = 'profiles'
#       LOOP
#         EXECUTE format($F$
#           UPDATE %%I.%%I t
#           SET %%I = p.keep_id
#           FROM pairs p
#           WHERE t.%%I = p.drop_id
#         $F$, r.fk_schema, r.fk_table, r.fk_column, r.fk_column);
#       END LOOP;
#     END$$;
#     ]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %%
from sqlalchemy import text
from db import get_engine, df_from_sql
import pandas as pd

engine = get_engine()

with engine.begin() as conn:
    # Pares (keep = public.com, drop = linkedin.com)
    conn.execute(text("CREATE TEMP TABLE pairs(keep_id bigint, drop_id bigint) ON COMMIT DROP;"))
    conn.execute(text("""
        INSERT INTO pairs(keep_id, drop_id)
        SELECT
          keep.profile_id  AS keep_id,
          drop_.profile_id AS drop_id
        FROM public.profiles keep
        JOIN public.profiles drop_
          ON rtrim(lower(
               regexp_replace(keep.linkedin_url,
                 '^(https?://)www\\.public\\.com/', '\\1www.linkedin.com/'
               )
             ), '/') = rtrim(lower(drop_.linkedin_url), '/')
        WHERE keep.linkedin_url ~* '^(https?://)www\\.public\\.com/';
    """))

# Listar tablas/columnas con FK → profiles(profile_id)
fk_list_sql = """
SELECT
  n.nspname  AS fk_schema,
  c.relname  AS fk_table,
  a.attname  AS fk_column
FROM pg_constraint con
JOIN pg_class      c  ON c.oid = con.conrelid
JOIN pg_namespace  n  ON n.oid = c.relnamespace
JOIN pg_class      cr ON cr.oid = con.confrelid
JOIN pg_namespace  nr ON nr.oid = cr.relnamespace
JOIN pg_attribute  a  ON a.attrelid = con.conrelid AND a.attnum = ANY (con.conkey)
WHERE con.contype   = 'f'
  AND nr.nspname    = 'public'
  AND cr.relname    = 'profiles';
"""

df_fks = df_from_sql(fk_list_sql, engine)
df_fks
# Out:
#   fk_schema           fk_table   fk_column
# 0    public         educations  profile_id
# 1    public        experiences  profile_id
# 2    public  profile_languages  profile_id
# 3    public     profile_skills  profile_id

# %%
from sqlalchemy import text

engine = get_engine()
updates_done = []

with engine.begin() as conn:
    for _, row in df_fks.iterrows():
        schema = row["fk_schema"]
        table  = row["fk_table"]
        col    = row["fk_column"]

        # Construimos SQL con identificadores entre comillas para seguridad
        sql = f'''
            UPDATE "{schema}"."{table}" t
            SET "{col}" = p.keep_id
            FROM pairs p
            WHERE t."{col}" = p.drop_id;
        '''
        res = conn.execute(text(sql))
        updates_done.append((f'{schema}.{table}.{col}', res.rowcount))

updates_done[:10], len(updates_done)
# Out:
# ---------------------------------------------------------------------------
# UndefinedTable                            Traceback (most recent call last)
# File d:\LATAM CONNECT\talento_latam_connect_V0.0\extraccion_talento_latam_connect\.venv\Lib\site-packages\sqlalchemy\engine\base.py:1967, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1966     if not evt_handled:
# -> 1967         self.dialect.do_execute(
#    1968             cursor, str_statement, effective_parameters, context
#    1969         )
#    1971 if self._has_events or self.engine._has_events:
#
# File d:\LATAM CONNECT\talento_latam_connect_V0.0\extraccion_talento_latam_connect\.venv\Lib\site-packages\sqlalchemy\engine\default.py:951, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     950 def do_execute(self, cursor, statement, parameters, context=None):
# --> 951     cursor.execute(statement, parameters)
#
# UndefinedTable: relation "pairs" does not exist
# LINE 4:             FROM pairs p
#                          ^
#
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# Cell In[18], line 19
#      12         # Construimos SQL con identificadores entre comillas para seguridad
#      13         sql = f'''
#      14             UPDATE "{schema}"."{table}" t
#      15             SET "{col}" = p.keep_id
#      16             FROM pairs p
#      17             WHERE t."{col}" = p.drop_id;
#      18         '''
# ---> 19         res = conn.execute(text(sql))
#      20         updates_done.append((f'{schema}.{table}.{col}', res.rowcount))
#      22 updates_done[:10], len(updates_done)
#
# File d:\LATAM CONNECT\talento_latam_connect_V0.0\extraccion_talento_latam_connect\.venv\Lib\site-packages\sqlalchemy\engine\base.py:1419, in Connection.execute(self, statement, parameters, execution_options)
#    1417     raise exc.ObjectNotExecutableError(statement) from err
#    1418 else:
# -> 1419     return meth(
#    1420         self,
#    1421         distilled_parameters,
#    1422         execution_options or NO_OPTIONS,
#    1423     )
#
# File d:\LATAM CONNECT\talento_latam_connect_V0.0\extraccion_talento_latam_connect\.venv\Lib\site-packages\sqlalchemy\sql\elements.py:526, in ClauseElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     524     if TYPE_CHECKING:
#     525         assert isinstance(self, Executable)
# --> 526     return connection._execute_clauseelement(
#     527         self, distilled_params, execution_options
#     528     )
#     529 else:
#     530     raise exc.ObjectNotExecutableError(self)
#
# File d:\LATAM CONNECT\talento_latam_connect_V0.0\extraccion_talento_latam_connect\.venv\Lib\site-packages\sqlalchemy\engine\base.py:1641, in Connection._execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1629 compiled_cache: Optional[CompiledCacheType] = execution_options.get(
#    1630     "compiled_cache", self.engine._compiled_cache
#    1631 )
#    1633 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1634     dialect=dialect,
#    1635     compiled_cache=compiled_cache,
#    (...)   1639     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1640 )
# -> 1641 ret = self._execute_context(
#    1642     dialect,
#    1643     dialect.execution_ctx_cls._init_compiled,
#    1644     compiled_sql,
#    1645     distilled_parameters,
#    1646     execution_options,
#    1647     compiled_sql,
#    1648     distilled_parameters,
#    1649     elem,
#    1650     extracted_params,
#    1651     cache_hit=cache_hit,
#    1652 )
#    1653 if has_events:
#    1654     self.dispatch.after_execute(
#    1655         self,
#    1656         elem,
#    (...)   1660         ret,
#    1661     )
#
# File d:\LATAM CONNECT\talento_latam_connect_V0.0\extraccion_talento_latam_connect\.venv\Lib\site-packages\sqlalchemy\engine\base.py:1846, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1844     return self._exec_insertmany_context(dialect, context)
#    1845 else:
# -> 1846     return self._exec_single_context(
#    1847         dialect, context, statement, parameters
#    1848     )
#
# File d:\LATAM CONNECT\talento_latam_connect_V0.0\extraccion_talento_latam_connect\.venv\Lib\site-packages\sqlalchemy\engine\base.py:1986, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1983     result = context._setup_result_proxy()
#    1985 except BaseException as e:
# -> 1986     self._handle_dbapi_exception(
#    1987         e, str_statement, effective_parameters, cursor, context
#    1988     )
#    1990 return result
#
# File d:\LATAM CONNECT\talento_latam_connect_V0.0\extraccion_talento_latam_connect\.venv\Lib\site-packages\sqlalchemy\engine\base.py:2355, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2353 elif should_wrap:
#    2354     assert sqlalchemy_exception is not None
# -> 2355     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2356 else:
#    2357     assert exc_info[1] is not None
#
# File d:\LATAM CONNECT\talento_latam_connect_V0.0\extraccion_talento_latam_connect\.venv\Lib\site-packages\sqlalchemy\engine\base.py:1967, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1965                 break
#    1966     if not evt_handled:
# -> 1967         self.dialect.do_execute(
#    1968             cursor, str_statement, effective_parameters, context
#    1969         )
#    1971 if self._has_events or self.engine._has_events:
#    1972     self.dispatch.after_cursor_execute(
#    1973         self,
#    1974         cursor,
#    (...)   1978         context.executemany,
#    1979     )
#
# File d:\LATAM CONNECT\talento_latam_connect_V0.0\extraccion_talento_latam_connect\.venv\Lib\site-packages\sqlalchemy\engine\default.py:951, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     950 def do_execute(self, cursor, statement, parameters, context=None):
# --> 951     cursor.execute(statement, parameters)
#
# ProgrammingError: (psycopg2.errors.UndefinedTable) relation "pairs" does not exist
# LINE 4:             FROM pairs p
#                          ^
#
# [SQL:
#             UPDATE "public"."educations" t
#             SET "profile_id" = p.keep_id
#             FROM pairs p
#             WHERE t."profile_id" = p.drop_id;
#         ]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %%
from sqlalchemy import text
import pandas as pd
from db import get_engine

engine = get_engine()

with engine.begin() as conn:
    # 1) Pairs dentro de la MISMA conexión
    conn.execute(text("""
        CREATE TEMP TABLE pairs(keep_id bigint, drop_id bigint) ON COMMIT PRESERVE ROWS;
    """))

    conn.execute(text("""
        INSERT INTO pairs(keep_id, drop_id)
        SELECT
          keep.profile_id  AS keep_id,
          drop_.profile_id AS drop_id
        FROM public.profiles keep
        JOIN public.profiles drop_
          ON rtrim(lower(
               regexp_replace(keep.linkedin_url,
                 '^(https?://)www\\.public\\.com/', '\\1www.linkedin.com/'
               )
             ), '/') = rtrim(lower(drop_.linkedin_url), '/')
        WHERE keep.linkedin_url ~* '^(https?://)www\\.public\\.com/';
    """))

    # 2) Todas las FKs que apuntan a public.profiles(profile_id)
    fk_list_sql = """
    SELECT
      n.nspname  AS fk_schema,
      c.relname  AS fk_table,
      a.attname  AS fk_column
    FROM pg_constraint con
    JOIN pg_class      c  ON c.oid = con.conrelid
    JOIN pg_namespace  n  ON n.oid = c.relnamespace
    JOIN pg_class      cr ON cr.oid = con.confrelid
    JOIN pg_namespace  nr ON nr.oid = cr.relnamespace
    JOIN pg_attribute  a  ON a.attrelid = con.conrelid AND a.attnum = ANY (con.conkey)
    WHERE con.contype   = 'f'
      AND nr.nspname    = 'public'
      AND cr.relname    = 'profiles';
    """
    fk_rows = conn.execute(text(fk_list_sql)).mappings().all()
    df_fks = pd.DataFrame(fk_rows)

    # Helper para obtener las columnas PK de una tabla
    def get_pk_cols(schema, table):
        pk_sql = text("""
            SELECT a.attname
            FROM pg_index i
            JOIN pg_class t   ON t.oid = i.indrelid
            JOIN pg_namespace n ON n.oid = t.relnamespace
            JOIN pg_attribute a ON a.attrelid = t.oid AND a.attnum = ANY(i.indkey)
            WHERE i.indisprimary = TRUE
              AND n.nspname = :schema
              AND t.relname = :table
            ORDER BY a.attnum;
        """)
        rows = conn.execute(pk_sql, {"schema": schema, "table": table}).scalars().all()
        return rows

    # 3) Para cada tabla hija: borrar potenciales duplicados y luego actualizar
    for _, r in df_fks.iterrows():
        schema = r["fk_schema"]
        table  = r["fk_table"]
        col    = r["fk_column"]

        pk_cols = get_pk_cols(schema, table)

        # 3a) Si la PK incluye la columna FK (caso típico: profile_languages(profile_id, lang_id))
        if col in pk_cols:
            other_pk = [c for c in pk_cols if c != col]
            if other_pk:
                # Construimos condiciones de igualdad en las otras columnas PK
                eq_conds = " AND ".join([f't2."{c}" = t."{c}"' for c in other_pk])

                # Borrar las filas del drop_id que colisionarían con keep_id
                delete_dup_sql = f'''
                    DELETE FROM "{schema}"."{table}" t
                    USING pairs p
                    WHERE t."{col}" = p.drop_id
                      AND EXISTS (
                        SELECT 1
                        FROM "{schema}"."{table}" t2
                        WHERE t2."{col}" = p.keep_id
                          AND {eq_conds}
                      );
                '''
                conn.execute(text(delete_dup_sql))
        # 3b) Actualizar todas las filas restantes del drop_id -> keep_id
        update_sql = f'''
            UPDATE "{schema}"."{table}" t
            SET "{col}" = p.keep_id
            FROM pairs p
            WHERE t."{col}" = p.drop_id;
        '''
        conn.execute(text(update_sql))

    # 4) Borrar duplicadas en profiles (las "drop") y corregir dominio en las "keep"
    conn.execute(text("""
        DELETE FROM public.profiles pr
        USING pairs p
        WHERE pr.profile_id = p.drop_id;
    """))

    conn.execute(text("""
        UPDATE public.profiles pr
        SET linkedin_url = regexp_replace(pr.linkedin_url,
                           '^(https?://)www\\.public\\.com/', '\\1www.linkedin.com/')
        FROM pairs p
        WHERE pr.profile_id = p.keep_id;
    """))

    # 5) Normalizar barra final
    conn.execute(text("""
        UPDATE public.profiles
        SET linkedin_url = rtrim(linkedin_url, '/')
        WHERE linkedin_url LIKE '%/';
    """))

    # Limpieza
    conn.execute(text("DROP TABLE IF EXISTS pairs;"))

print("✅ Merge OK: FKs reasignados con deduplicación previa, duplicados borrados y URLs arregladas.")
# Out:
# ✅ Merge OK: FKs reasignados con deduplicación previa, duplicados borrados y URLs arregladas.

# %%
from db import df_from_sql

# 0 con public.com
df_from_sql("""
SELECT COUNT(*) AS restantes_public
FROM public.profiles
WHERE linkedin_url ~* '^(https?://)www\\.public\\.com/';
""", engine)
# Out:
#    restantes_public
# 0                 5
